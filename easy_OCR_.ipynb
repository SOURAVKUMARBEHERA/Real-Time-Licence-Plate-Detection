# %%
# !pip install easyocr

# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
from IPython.display import Image

# %%
Image("/content/scaned_img_1.jpg")

# %%
reader = easyocr.Reader(['en'])

# %%
output = reader.readtext('/scaned_img_0.jpg')

# %%
output
# Out:
# [([[0, 12], [141, 12], [141, 50], [0, 50]], '1H12DE1433', 0.8371905702899359)]
